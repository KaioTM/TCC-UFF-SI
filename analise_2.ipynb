# %% [markdown]
# # Relatório de Análise - TCC

# %% [markdown]
# ## Análise de avaliações de desempenho para o TCC

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
pd.read_csv('C:/Users/kaiom/Documents/TCC/Dados/Atualizados/Cliente_2/report_notas_comp.csv', low_memory = False, sep=';')
# Out:
#        ID do Modelo de Formulário  Nome do modelo do formulário  \
# 0                             725                          2014
# 1                             725                          2014
# 2                             725                          2014
# 3                             725                          2014
# 4                             725                          2014
# 5                             725                          2014
# 6                             725                          2014
# 7                             906                          2015
# 8                             906                          2015
# 9                             906                          2015
# 10                            906                          2015
# 11                            906                          2015
# 12                            906                          2015
# 13                            906                          2015
# 14                            906                          2015
# 15                            906                          2015
# 16                            906                          2015
# 17                            906                          2015
# 18                            906                          2015
# 19                            906                          2015
# 20                            906                          2015
# 21                            906                          2015
# 22                            906                          2015
# 23                            906                          2015
# 24                            906                          2015
# 25                            906                          2015
# 26                            906                          2015
# 27                            906                          2015
# 28                            906                          2015
# 29                            906                          2015
# ...                           ...                           ...
# 60707                        1181                          2019
# 60708                        1179                          2019
# 60709                        1179                          2019
# 60710                        1179                          2019
# 60711                        1179                          2019
# 60712                        1179                          2019
# 60713                        1179                          2019
# 60714                        1179                          2019
# 60715                        1179                          2019
# 60716                        1179                          2019
# 60717                        1179                          2019
# 60718                        1179                          2019
# 60719                        1179                          2019
# 60720                        1179                          2019
# 60721                        1179                          2019
# 60722                        1179                          2019
# 60723                        1179                          2019
# 60724                        1179                          2019
# 60725                        1179                          2019
# 60726                        1179                          2019
# 60727                        1179                          2019
# 60728                        1179                          2019
# 60729                        1181                          2019
# 60730                        1181                          2019
# 60731                        1181                          2019
# 60732                        1181                          2019
# 60733                        1181                          2019
# 60734                        1181                          2019
# 60735                        1181                          2019
# 60736                        1181                          2019
#
#        ID do Documento Assunto Username  \
# 0                13353           BRARS9
# 1                13353           BRARS9
# 2                13353           BRARS9
# 3                13353           BRARS9
# 4                13353           BRARS9
# 5                13353           BRARS9
# 6                13353           BRARS9
# 7                22085            BRFGB
# 8                22085            BRFGB
# 9                22085            BRFGB
# 10               22085            BRFGB
# 11               22085            BRFGB
# 12               22085            BRFGB
# 13               22085            BRFGB
# 14               22086            BRTCL
# 15               22086            BRTCL
# 16               22086            BRTCL
# 17               22086            BRTCL
# 18               22086            BRTCL
# 19               22086            BRTCL
# 20               22086            BRTCL
# 21               22089          BREGAFS
# 22               22089          BREGAFS
# 23               22089          BREGAFS
# 24               22089          BREGAFS
# 25               22089          BREGAFS
# 26               22089          BREGAFS
# 27               22089          BREGAFS
# 28               22091            BRPCJ
# 29               22091            BRPCJ
# ...                ...              ...
# 60707            44356           BRTRS6
# 60708            44810           BRMGAM
# 60709            44810           BRMGAM
# 60710            44810           BRMGAM
# 60711            44810           BRMGAM
# 60712            44810           BRMGAM
# 60713            44810           BRMGAM
# 60714            44810           BRMGAM
# 60715            44969           BRWFS2
# 60716            44969           BRWFS2
# 60717            44969           BRWFS2
# 60718            44969           BRWFS2
# 60719            44969           BRWFS2
# 60720            44969           BRWFS2
# 60721            44969           BRWFS2
# 60722            44983           BRZSTM
# 60723            44983           BRZSTM
# 60724            44983           BRZSTM
# 60725            44983           BRZSTM
# 60726            44983           BRZSTM
# 60727            44983           BRZSTM
# 60728            44983           BRZSTM
# 60729            45434           BRWRS1
# 60730            45434           BRWRS1
# 60731            45434           BRWRS1
# 60732            45434           BRWRS1
# 60733            45434           BRWRS1
# 60734            45434           BRWRS1
# 60735            45434           BRWRS1
# 60736            45434           BRWRS1
#
#                  Departamento no formulário preenchido  \
# 0                     COM - [11921031] - Ele - Fashion
# 1                     COM - [11921031] - Ele - Fashion
# 2                     COM - [11921031] - Ele - Fashion
# 3                     COM - [11921031] - Ele - Fashion
# 4                     COM - [11921031] - Ele - Fashion
# 5                     COM - [11921031] - Ele - Fashion
# 6                     COM - [11921031] - Ele - Fashion
# 7      COM - [11920702] - Planning/Inteligencia de Neg
# 8      COM - [11920702] - Planning/Inteligencia de Neg
# 9      COM - [11920702] - Planning/Inteligencia de Neg
# 10     COM - [11920702] - Planning/Inteligencia de Neg
# 11     COM - [11920702] - Planning/Inteligencia de Neg
# 12     COM - [11920702] - Planning/Inteligencia de Neg
# 13     COM - [11920702] - Planning/Inteligencia de Neg
# 14                    MKT - [11933001] - MARKETING ADM
# 15                    MKT - [11933001] - MARKETING ADM
# 16                    MKT - [11933001] - MARKETING ADM
# 17                    MKT - [11933001] - MARKETING ADM
# 18                    MKT - [11933001] - MARKETING ADM
# 19                    MKT - [11933001] - MARKETING ADM
# 20                    MKT - [11933001] - MARKETING ADM
# 21              DRE - [11930001] - Diretoria Executiva
# 22              DRE - [11930001] - Diretoria Executiva
# 23              DRE - [11930001] - Diretoria Executiva
# 24              DRE - [11930001] - Diretoria Executiva
# 25              DRE - [11930001] - Diretoria Executiva
# 26              DRE - [11930001] - Diretoria Executiva
# 27              DRE - [11930001] - Diretoria Executiva
# 28              DRE - [11930001] - Diretoria Executiva
# 29              DRE - [11930001] - Diretoria Executiva
# ...                                                ...
# 60707       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60708       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60709       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60710       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60711       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60712       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60713       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60714       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60715                 [11920706] - PROJETOS E CONTROLE
# 60716                 [11920706] - PROJETOS E CONTROLE
# 60717                 [11920706] - PROJETOS E CONTROLE
# 60718                 [11920706] - PROJETOS E CONTROLE
# 60719                 [11920706] - PROJETOS E CONTROLE
# 60720                 [11920706] - PROJETOS E CONTROLE
# 60721                 [11920706] - PROJETOS E CONTROLE
# 60722       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60723       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60724       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60725       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60726       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60727       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60728       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO
# 60729                 [11920706] - PROJETOS E CONTROLE
# 60730                 [11920706] - PROJETOS E CONTROLE
# 60731                 [11920706] - PROJETOS E CONTROLE
# 60732                 [11920706] - PROJETOS E CONTROLE
# 60733                 [11920706] - PROJETOS E CONTROLE
# 60734                 [11920706] - PROJETOS E CONTROLE
# 60735                 [11920706] - PROJETOS E CONTROLE
# 60736                 [11920706] - PROJETOS E CONTROLE
#
#       Classificação Global de Competência                Nome da Competência  \
# 0                           Sem pontuação                               Foco
# 1                           Sem pontuação           Juntos Somos Mais Fortes
# 2                           Sem pontuação                          Liderança
# 3                           Sem pontuação     Autonomia com Responsabilidade
# 4                           Sem pontuação                         Influência
# 5                           Sem pontuação                          Superação
# 6                           Sem pontuação  Compromisso com o Desenvolvimento
# 7                                       2                          Liderança
# 8                                       2     Autonomia com Responsabilidade
# 9                                       2                          Superação
# 10                                      2  Compromisso com o Desenvolvimento
# 11                                      2                               Foco
# 12                                      2           Juntos Somos Mais Fortes
# 13                                      2                         Influência
# 14                                      1     Autonomia com Responsabilidade
# 15                                      1  Compromisso com o Desenvolvimento
# 16                                      1                               Foco
# 17                                      1                          Liderança
# 18                                      1           Juntos Somos Mais Fortes
# 19                                      1                         Influência
# 20                                      1                          Superação
# 21                                      3           Juntos Somos Mais Fortes
# 22                                      3     Autonomia com Responsabilidade
# 23                                      3                          Superação
# 24                                      3  Compromisso com o Desenvolvimento
# 25                                      3                          Liderança
# 26                                      3                               Foco
# 27                                      3                         Influência
# 28                                      3                          Liderança
# 29                                      3           Juntos Somos Mais Fortes
# ...                                   ...                                ...
# 60707                                   2                  Atitude de Servir
# 60708                                   2                               Foco
# 60709                                   2  Compromisso com o Desenvolvimento
# 60710                                   2                         Eficiência
# 60711                                   2                         Influência
# 60712                                   2                  Atitude de Servir
# 60713                                   2              Execução e Resultados
# 60714                                   2           Juntos Somos Mais Fortes
# 60715                                   1                         Eficiência
# 60716                                   1                         Influência
# 60717                                   1                  Atitude de Servir
# 60718                                   1              Execução e Resultados
# 60719                                   1           Juntos Somos Mais Fortes
# 60720                                   1  Compromisso com o Desenvolvimento
# 60721                                   1                               Foco
# 60722                                   2                               Foco
# 60723                                   2                  Atitude de Servir
# 60724                                   2  Compromisso com o Desenvolvimento
# 60725                                   2                         Eficiência
# 60726                                   2                         Influência
# 60727                                   2              Execução e Resultados
# 60728                                   2           Juntos Somos Mais Fortes
# 60729                                   2                          Liderança
# 60730                                   2  Compromisso com o Desenvolvimento
# 60731                                   2                         Eficiência
# 60732                                   2              Execução e Resultados
# 60733                                   2           Juntos Somos Mais Fortes
# 60734                                   2                         Influência
# 60735                                   2                               Foco
# 60736                                   2                  Atitude de Servir
#
#        Classificação oficial de competência
# 0                                         2
# 1                                         2
# 2                                         2
# 3                                         2
# 4                                         2
# 5                                         2
# 6                                         2
# 7                                         2
# 8                                         2
# 9                                         2
# 10                                        2
# 11                                        1
# 12                                        2
# 13                                        3
# 14                                        2
# 15                                        2
# 16                                        2
# 17                                        1
# 18                                        1
# 19                                        1
# 20                                        3
# 21                                        2
# 22                                        3
# 23                                        3
# 24                                        3
# 25                                        3
# 26                                        3
# 27                                        3
# 28                                        2
# 29                                        2
# ...                                     ...
# 60707                                     2
# 60708                                     2
# 60709                                     2
# 60710                                     2
# 60711                                     2
# 60712                                     2
# 60713                                     2
# 60714                                     2
# 60715                                     2
# 60716                                     2
# 60717                                     2
# 60718                                     2
# 60719                                     2
# 60720                                     3
# 60721                                     1
# 60722                                     2
# 60723                                     2
# 60724                                     2
# 60725                                     2
# 60726                                     2
# 60727                                     2
# 60728                                     2
# 60729                                     1
# 60730                                     2
# 60731                                     2
# 60732                                     2
# 60733                                     2
# 60734                                     2
# 60735                                     2
# 60736                                     2
#
# [60737 rows x 8 columns]

# %%
dados = pd.read_csv('C:/Users/kaiom/Documents/TCC/Dados/Atualizados/Cliente_2/report_notas_comp.csv', low_memory = False, sep=';')

# %%
dados[['Assunto Username']].drop_duplicates()
# Out:
#       Assunto Username
# 0               BRARS9
# 7                BRFGB
# 14               BRTCL
# 21             BREGAFS
# 28               BRPCJ
# 35               BRLGG
# 42              BRBSGF
# 49                 BRJ
# 56                BRRU
# 63              BRTRBC
# 70               BRCSG
# 77              BRRCS7
# 84               BRBRM
# 91             BRACCJ2
# 98              BRALGB
# 105             BRACVC
# 112              BREOL
# 119            BRMASA1
# 126              BRMON
# 133             BRFLS1
# 140             BRLFF1
# 147            BRASC28
# 154              BRGCM
# 161             BRACSA
# 168             BRKCMS
# 175             BRMM11
# 182             BRDGP1
# 189             BRVRC8
# 196            BRCAS24
# 203            BRRSM15
# ...                ...
# 59751            BRJRB
# 59758            BRFCA
# 59766            BRWSL
# 59773           BRGEDP
# 59789            BRCSQ
# 59811            BRWRC
# 59842            BRVAA
# 59885             BRPE
# 59899           BRPRC1
# 59906            BRAM4
# 59913          BRNMARR
# 60004           BRMBL6
# 60193            BRAB5
# 60221          BRJMS15
# 60229           BRJFS3
# 60265           BRDGC1
# 60293          BRRSS42
# 60300           BRMCA2
# 60335            BRCFF
# 60342           BRLIO2
# 60471           BRACT3
# 60508           BRCAAC
# 60524            BRBMP
# 60532           BRCML5
# 60560           BRRNRL
# 60567           BRLMGA
# 60612           BRIAFS
# 60641          BRJRS15
# 60670           BRMPPL
# 60715           BRWFS2
#
# [2882 rows x 1 columns]

# %%
competenciasValidas = dados[['Nome do modelo do formulário', 'Nome da Competência']]
competenciasValidas.head()
# Out:
#    Nome do modelo do formulário             Nome da Competência
# 0                          2014                            Foco
# 1                          2014        Juntos Somos Mais Fortes
# 2                          2014                       Liderança
# 3                          2014  Autonomia com Responsabilidade
# 4                          2014                      Influência

# %%
competenciasValidas = competenciasValidas.drop_duplicates()
competenciasValidas
# Out:
#        Nome do modelo do formulário                Nome da Competência
# 0                              2014                               Foco
# 1                              2014           Juntos Somos Mais Fortes
# 2                              2014                          Liderança
# 3                              2014     Autonomia com Responsabilidade
# 4                              2014                         Influência
# 5                              2014                          Superação
# 6                              2014  Compromisso com o Desenvolvimento
# 7                              2015                          Liderança
# 8                              2015     Autonomia com Responsabilidade
# 9                              2015                          Superação
# 10                             2015  Compromisso com o Desenvolvimento
# 11                             2015                               Foco
# 12                             2015           Juntos Somos Mais Fortes
# 13                             2015                         Influência
# 6815                           2016                               Foco
# 6816                           2016           Juntos Somos Mais Fortes
# 6817                           2016                          Superação
# 6818                           2016  Compromisso com o Desenvolvimento
# 6819                           2016                          Liderança
# 6820                           2016                         Influência
# 6821                           2016     Autonomia com Responsabilidade
# 7197                           2017                         Influência
# 7198                           2017           Juntos Somos Mais Fortes
# 7199                           2017                         Eficiência
# 7200                           2017                               Foco
# 7201                           2017              Execução e Resultados
# 7202                           2017  Compromisso com o Desenvolvimento
# 7259                           2017                          Liderança
# 38773                          2018                               Foco
# 38774                          2018                  Atitude de Servir
# 38775                          2018           Juntos Somos Mais Fortes
# 38776                          2018                         Influência
# 38777                          2018              Execução e Resultados
# 38778                          2018                          Liderança
# 38779                          2018  Compromisso com o Desenvolvimento
# 38780                          2018                         Eficiência
# 48050                          2019  Compromisso com o Desenvolvimento
# 48051                          2019                               Foco
# 48052                          2019                  Atitude de Servir
# 48053                          2019              Execução e Resultados
# 48054                          2019                          Liderança
# 48055                          2019                         Eficiência
# 48056                          2019           Juntos Somos Mais Fortes
# 48057                          2019                         Influência

# %%
competencias = pd.DataFrame(competenciasValidas.groupby('Nome da Competência').size(), columns=None).reset_index()

# %%
competencias.columns = ['Competencia','Frequencia']
competencias
# Out:
#                          Competencia  Frequencia
# 0                  Atitude de Servir           2
# 1     Autonomia com Responsabilidade           3
# 2  Compromisso com o Desenvolvimento           6
# 3                         Eficiência           3
# 4              Execução e Resultados           3
# 5                               Foco           6
# 6                         Influência           6
# 7           Juntos Somos Mais Fortes           6
# 8                          Liderança           6
# 9                          Superação           3

# %%
competenciasTodosAnos = competencias[ competencias['Frequencia'] == 6 ]
competenciasTodosAnos
# Out:
#                          Competencia  Frequencia
# 2  Compromisso com o Desenvolvimento           6
# 5                               Foco           6
# 6                         Influência           6
# 7           Juntos Somos Mais Fortes           6
# 8                          Liderança           6

# %%
listaCompValidas = list(competenciasTodosAnos['Competencia'])
listaCompValidas
# Out:
# ['Compromisso com o Desenvolvimento',
#  'Foco',
#  'Influência',
#  'Juntos Somos Mais Fortes',
#  'Liderança']

# %%
selecao = dados['Nome da Competência'].isin(listaCompValidas)

# %%
dados_selecionados = dados[selecao]
dados_selecionados.columns = ['idModelo','nomeModelo','idDocumento','userId','area','notaGlobal','nomeCompetencia','gestorAv']

# %%
participantesAno = dados_selecionados[['idModelo','userId']].drop_duplicates()
participantesAno = participantesAno.sort_values(by=['userId'])
participantesAno = pd.DataFrame(participantesAno.groupby('userId').size(), columns=None).reset_index()
participantesAno.columns = ['Usuario','Frequencia']
participantesValidos = participantesAno[ participantesAno['Frequencia'] == 6 ]
participantesValidos = participantesValidos.drop_duplicates()
listaParticipantesValidos = list(participantesValidos['Usuario'])
selecaoParticipantes = dados_selecionados['userId'].isin(listaParticipantesValidos)
dadosFinais = dados_selecionados[selecaoParticipantes]
dadosFinais
# Out:
#        idModelo  nomeModelo  idDocumento   userId  \
# 7           906        2015        22085    BRFGB
# 10          906        2015        22085    BRFGB
# 11          906        2015        22085    BRFGB
# 12          906        2015        22085    BRFGB
# 13          906        2015        22085    BRFGB
# 56          906        2015        22116     BRRU
# 58          906        2015        22116     BRRU
# 59          906        2015        22116     BRRU
# 60          906        2015        22116     BRRU
# 61          906        2015        22116     BRRU
# 71          906        2015        22122    BRCSG
# 72          906        2015        22122    BRCSG
# 74          906        2015        22122    BRCSG
# 75          906        2015        22122    BRCSG
# 76          906        2015        22122    BRCSG
# 98          906        2015        22137   BRALGB
# 99          906        2015        22137   BRALGB
# 101         906        2015        22137   BRALGB
# 102         906        2015        22137   BRALGB
# 103         906        2015        22137   BRALGB
# 120         906        2015        22141  BRMASA1
# 121         906        2015        22141  BRMASA1
# 123         906        2015        22141  BRMASA1
# 124         906        2015        22141  BRMASA1
# 125         906        2015        22141  BRMASA1
# 168         906        2015        22165   BRKCMS
# 170         906        2015        22165   BRKCMS
# 172         906        2015        22165   BRKCMS
# 173         906        2015        22165   BRKCMS
# 174         906        2015        22165   BRKCMS
# ...         ...         ...          ...      ...
# 60586      1179        2019        44703    BRJC1
# 60587      1179        2019        44703    BRJC1
# 60589      1179        2019        44444    BRATJ
# 60592      1179        2019        44444    BRATJ
# 60593      1179        2019        44444    BRATJ
# 60594      1179        2019        44444    BRATJ
# 60604      1181        2019        43983  BRACCJ1
# 60605      1181        2019        43983  BRACCJ1
# 60608      1181        2019        43983  BRACCJ1
# 60609      1181        2019        43983  BRACCJ1
# 60610      1181        2019        43983  BRACCJ1
# 60619      1179        2019        44626   BRFMP1
# 60622      1179        2019        44626   BRFMP1
# 60623      1179        2019        44626   BRFMP1
# 60624      1179        2019        44626   BRFMP1
# 60633      1179        2019        44728   BRKFSO
# 60634      1179        2019        44728   BRKFSO
# 60637      1179        2019        44728   BRKFSO
# 60638      1179        2019        44728   BRKFSO
# 60639      1179        2019        44728   BRKFSO
# 60700      1181        2019        44356   BRTRS6
# 60701      1181        2019        44356   BRTRS6
# 60704      1181        2019        44356   BRTRS6
# 60705      1181        2019        44356   BRTRS6
# 60706      1181        2019        44356   BRTRS6
# 60729      1181        2019        45434   BRWRS1
# 60730      1181        2019        45434   BRWRS1
# 60733      1181        2019        45434   BRWRS1
# 60734      1181        2019        45434   BRWRS1
# 60735      1181        2019        45434   BRWRS1
#
#                                                   area notaGlobal  \
# 7      COM - [11920702] - Planning/Inteligencia de Neg          2
# 10     COM - [11920702] - Planning/Inteligencia de Neg          2
# 11     COM - [11920702] - Planning/Inteligencia de Neg          2
# 12     COM - [11920702] - Planning/Inteligencia de Neg          2
# 13     COM - [11920702] - Planning/Inteligencia de Neg          2
# 56             DDV - [11800010] - Diretoria/Ger. Lojas          1
# 58             DDV - [11800010] - Diretoria/Ger. Lojas          1
# 59             DDV - [11800010] - Diretoria/Ger. Lojas          1
# 60             DDV - [11800010] - Diretoria/Ger. Lojas          1
# 61             DDV - [11800010] - Diretoria/Ger. Lojas          1
# 71             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 72             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 74             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 75             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 76             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 98             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 99             DDV - [11800010] - Diretoria/Ger. Lojas          2
# 101            DDV - [11800010] - Diretoria/Ger. Lojas          2
# 102            DDV - [11800010] - Diretoria/Ger. Lojas          2
# 103            DDV - [11800010] - Diretoria/Ger. Lojas          2
# 120    RFS - [99000200] - RFS - Diretoria de Lojas RFS          2
# 121    RFS - [99000200] - RFS - Diretoria de Lojas RFS          2
# 123    RFS - [99000200] - RFS - Diretoria de Lojas RFS          2
# 124    RFS - [99000200] - RFS - Diretoria de Lojas RFS          2
# 125    RFS - [99000200] - RFS - Diretoria de Lojas RFS          2
# 168                COM - [11921021] - Ela - Acessorios          2
# 170                COM - [11921021] - Ela - Acessorios          2
# 172                COM - [11921021] - Ela - Acessorios          2
# 173                COM - [11921021] - Ela - Acessorios          2
# 174                COM - [11921021] - Ela - Acessorios          2
# ...                                                ...        ...
# 60586  [11931104] - INFRAESTRUTURA DE TELECOMUNICACOES          2
# 60587  [11931104] - INFRAESTRUTURA DE TELECOMUNICACOES          2
# 60589                 [11930204] - VESTUARIO  - FISCAL          1
# 60592                 [11930204] - VESTUARIO  - FISCAL          1
# 60593                 [11930204] - VESTUARIO  - FISCAL          1
# 60594                 [11930204] - VESTUARIO  - FISCAL          1
# 60604            [11931529] - IT MERCHANDISE SOLUTIONS          2
# 60605            [11931529] - IT MERCHANDISE SOLUTIONS          2
# 60608            [11931529] - IT MERCHANDISE SOLUTIONS          2
# 60609            [11931529] - IT MERCHANDISE SOLUTIONS          2
# 60610            [11931529] - IT MERCHANDISE SOLUTIONS          2
# 60619         [11931102] - INFRAESTRUTURA DE OPERACOES          2
# 60622         [11931102] - INFRAESTRUTURA DE OPERACOES          2
# 60623         [11931102] - INFRAESTRUTURA DE OPERACOES          2
# 60624         [11931102] - INFRAESTRUTURA DE OPERACOES          2
# 60633       [11930603] - CCI-CENTRAL COMPRAS INDIRETOS          2
# 60634       [11930603] - CCI-CENTRAL COMPRAS INDIRETOS          2
# 60637       [11930603] - CCI-CENTRAL COMPRAS INDIRETOS          2
# 60638       [11930603] - CCI-CENTRAL COMPRAS INDIRETOS          2
# 60639       [11930603] - CCI-CENTRAL COMPRAS INDIRETOS          2
# 60700       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO          2
# 60701       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO          2
# 60704       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO          2
# 60705       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO          2
# 60706       [11920701] - VESTUARIO  - PLANEJ./ALOCACAO          2
# 60729                 [11920706] - PROJETOS E CONTROLE          2
# 60730                 [11920706] - PROJETOS E CONTROLE          2
# 60733                 [11920706] - PROJETOS E CONTROLE          2
# 60734                 [11920706] - PROJETOS E CONTROLE          2
# 60735                 [11920706] - PROJETOS E CONTROLE          2
#
#                          nomeCompetencia  gestorAv
# 7                              Liderança         2
# 10     Compromisso com o Desenvolvimento         2
# 11                                  Foco         1
# 12              Juntos Somos Mais Fortes         2
# 13                            Influência         3
# 56                                  Foco         2
# 58     Compromisso com o Desenvolvimento         1
# 59                             Liderança         1
# 60                            Influência         1
# 61              Juntos Somos Mais Fortes         1
# 71                                  Foco         2
# 72              Juntos Somos Mais Fortes         2
# 74                            Influência         2
# 75     Compromisso com o Desenvolvimento         2
# 76                             Liderança         2
# 98                                  Foco         2
# 99              Juntos Somos Mais Fortes         2
# 101                           Influência         2
# 102                            Liderança         2
# 103    Compromisso com o Desenvolvimento         2
# 120                                 Foco         2
# 121             Juntos Somos Mais Fortes         2
# 123                           Influência         2
# 124    Compromisso com o Desenvolvimento         2
# 125                            Liderança         2
# 168             Juntos Somos Mais Fortes         2
# 170                                 Foco         2
# 172                           Influência         2
# 173                            Liderança         2
# 174    Compromisso com o Desenvolvimento         3
# ...                                  ...       ...
# 60586                         Influência         2
# 60587                               Foco         1
# 60589  Compromisso com o Desenvolvimento         1
# 60592           Juntos Somos Mais Fortes         2
# 60593                         Influência         2
# 60594                               Foco         1
# 60604                          Liderança         1
# 60605  Compromisso com o Desenvolvimento         2
# 60608           Juntos Somos Mais Fortes         2
# 60609                         Influência         2
# 60610                               Foco         2
# 60619  Compromisso com o Desenvolvimento         3
# 60622           Juntos Somos Mais Fortes         3
# 60623                         Influência         3
# 60624                               Foco         2
# 60633                          Liderança         2
# 60634  Compromisso com o Desenvolvimento         2
# 60637           Juntos Somos Mais Fortes         3
# 60638                         Influência         2
# 60639                               Foco         2
# 60700                          Liderança         3
# 60701  Compromisso com o Desenvolvimento         2
# 60704           Juntos Somos Mais Fortes         2
# 60705                         Influência         2
# 60706                               Foco         3
# 60729                          Liderança         1
# 60730  Compromisso com o Desenvolvimento         2
# 60733           Juntos Somos Mais Fortes         2
# 60734                         Influência         2
# 60735                               Foco         2
#
# [11158 rows x 8 columns]

# %% [markdown]
# ## Número de avaliados por ano

# %%
infoAvaliacoes = dadosFinais[['nomeModelo','userId']].drop_duplicates()
infoAvaliacoes = pd.DataFrame(infoAvaliacoes.groupby('nomeModelo').size(), columns=None).reset_index()
infoAvaliacoes
# Out:
#    nomeModelo    0
# 0        2014  386
# 1        2015  386
# 2        2016  386
# 3        2017  386
# 4        2018  386
# 5        2019  386

# %%
df = dadosFinais.pivot_table(index=["nomeModelo","userId","nomeCompetencia"], values="gestorAv")
df
# Out:
#                                                       gestorAv
# nomeModelo userId  nomeCompetencia
# 2014       BRAACN  Compromisso com o Desenvolvimento         2
#                    Foco                                      1
#                    Influência                                3
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 3
#            BRAAF3  Compromisso com o Desenvolvimento         2
#                    Foco                                      1
#                    Influência                                2
#                    Juntos Somos Mais Fortes                  3
#                    Liderança                                 3
#            BRAAMGM Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                2
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 2
#            BRAAS   Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                1
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 1
#            BRABSG  Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                2
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 2
#            BRACCJ1 Compromisso com o Desenvolvimento         2
#                    Foco                                      3
#                    Influência                                3
#                    Juntos Somos Mais Fortes                  3
#                    Liderança                                 3
# ...                                                        ...
# 2019       BRWBN   Influência                                2
#                    Juntos Somos Mais Fortes                  3
#                    Liderança                                 2
#            BRWBS2  Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                1
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 2
#            BRWCM2  Compromisso com o Desenvolvimento         1
#                    Foco                                      2
#                    Influência                                3
#                    Juntos Somos Mais Fortes                  2
#            BRWDM   Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                1
#                    Juntos Somos Mais Fortes                  2
#            BRWLMC  Compromisso com o Desenvolvimento         2
#                    Foco                                      3
#                    Influência                                1
#                    Juntos Somos Mais Fortes                  2
#            BRWOD   Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                2
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 2
#            BRWRS1  Compromisso com o Desenvolvimento         2
#                    Foco                                      2
#                    Influência                                2
#                    Juntos Somos Mais Fortes                  2
#                    Liderança                                 1
#
# [11158 rows x 1 columns]

# %% [markdown]
# ## Join entre avaliações e PDI

# %%
pdiMapeado = pd.read_csv('C:/Users/kaiom/Documents/TCC/Dados/Atualizados/Cliente_2/report_pdi.csv', low_memory = False, sep=';')
pdiMapeadoAjustado = pdiMapeado [['Nome do plano do Objetivo de Desenvolvimento','Proprietário do Objetivo Username','Nome da Competência','Nome da Competência']]
pdiMapeadoAjustado.columns = ["nomeModelo","userId","nomeCompetencia",'Competência']
pdiMapeadoAjustado = pdiMapeadoAjustado.set_index(["nomeModelo","userId","nomeCompetencia"])
pdiMapeadoAjustado.head()
# Out:
#                                    Competência
# nomeModelo userId  nomeCompetencia
# 2017       BRMDAF  Eficiência       Eficiência
# 2015       BRMO4   Eficiência       Eficiência
# 2019       BRDDAS2 Eficiência       Eficiência
#            BREOR3  Eficiência       Eficiência
# 2015       BRECSV4 Eficiência       Eficiência

# %%
listaPdiMapeadoPorCompetencia = pd.merge(df.reset_index(), pdiMapeadoAjustado.reset_index(), on=["nomeModelo","userId","nomeCompetencia"], how ='left')
listaPdiMapeadoPorCompetencia.columns = [['Ano', 'userId','Competência','gestorAv','PDI?']]

# %%
listaPdiMapeadoPorCompetencia['PDI?'] = listaPdiMapeadoPorCompetencia['PDI?'].replace(to_replace =['Compromisso com o Desenvolvimento',
 'Foco',
 'Influência',
 'Juntos Somos Mais Fortes',
 'Liderança'], value ="Sim")

listaPdiMapeadoPorCompetencia['PDI?'] = listaPdiMapeadoPorCompetencia['PDI?'].fillna('Não')

# %%
listaPdiMapeadoPorCompetencia.columns = ['anoAv','colaborador','comp','avaliacao','pdiAnoAnterior']

# %%
listaPdiMapeadoPorCompetencia.pivot_table(index=["colaborador","comp"], columns=['anoAv'], values=["avaliacao"])
# Out:
#                                               avaliacao                      \
# anoAv                                              2014 2015 2016 2017 2018
# colaborador comp
# BRAACN      Compromisso com o Desenvolvimento       2.0  2.0  3.0  2.0  2.0
#             Foco                                    1.0  2.0  2.0  2.0  2.0
#             Influência                              3.0  3.0  2.0  2.0  2.0
#             Juntos Somos Mais Fortes                2.0  3.0  2.0  3.0  2.0
#             Liderança                               3.0  3.0  3.0  2.0  3.0
# BRAAF3      Compromisso com o Desenvolvimento       2.0  2.0  3.0  3.0  3.0
#             Foco                                    1.0  1.0  1.0  2.0  3.0
#             Influência                              2.0  2.0  3.0  2.0  2.0
#             Juntos Somos Mais Fortes                3.0  2.0  2.0  2.0  2.0
#             Liderança                               3.0  3.0  2.0  3.0  3.0
# BRAAMGM     Compromisso com o Desenvolvimento       2.0  2.0  2.0  2.0  2.0
#             Foco                                    2.0  2.0  2.0  2.0  2.0
#             Influência                              2.0  2.0  2.0  2.0  2.0
#             Juntos Somos Mais Fortes                2.0  2.0  3.0  2.0  2.0
#             Liderança                               2.0  2.0  3.0  NaN  NaN
# BRAAS       Compromisso com o Desenvolvimento       2.0  2.0  2.0  3.0  3.0
#             Foco                                    2.0  2.0  2.0  1.0  2.0
#             Influência                              1.0  3.0  3.0  1.0  2.0
#             Juntos Somos Mais Fortes                2.0  3.0  2.0  2.0  3.0
#             Liderança                               1.0  2.0  2.0  2.0  2.0
# BRABSG      Compromisso com o Desenvolvimento       2.0  2.0  1.0  2.0  2.0
#             Foco                                    2.0  2.0  2.0  2.0  2.0
#             Influência                              2.0  2.0  1.0  2.0  2.0
#             Juntos Somos Mais Fortes                2.0  3.0  2.0  2.0  2.0
#             Liderança                               2.0  2.0  1.0  1.0  2.0
# BRACCJ1     Compromisso com o Desenvolvimento       2.0  1.0  2.0  2.0  2.0
#             Foco                                    3.0  2.0  2.0  3.0  2.0
#             Influência                              3.0  3.0  1.0  2.0  2.0
#             Juntos Somos Mais Fortes                3.0  3.0  2.0  2.0  2.0
#             Liderança                               3.0  2.0  1.0  2.0  1.0
# ...                                                 ...  ...  ...  ...  ...
# BRWBS2      Compromisso com o Desenvolvimento       1.0  2.0  2.0  3.0  3.0
#             Foco                                    1.0  2.0  2.0  2.0  2.0
#             Influência                              2.0  3.0  3.0  3.0  3.0
#             Juntos Somos Mais Fortes                2.0  2.0  2.0  3.0  2.0
#             Liderança                               2.0  2.0  2.0  2.0  3.0
# BRWCM2      Compromisso com o Desenvolvimento       1.0  1.0  1.0  2.0  1.0
#             Foco                                    1.0  2.0  2.0  1.0  1.0
#             Influência                              1.0  2.0  2.0  2.0  3.0
#             Juntos Somos Mais Fortes                1.0  2.0  2.0  2.0  3.0
#             Liderança                               1.0  1.0  2.0  NaN  NaN
# BRWDM       Compromisso com o Desenvolvimento       2.0  3.0  3.0  3.0  1.0
#             Foco                                    2.0  3.0  3.0  3.0  1.0
#             Influência                              2.0  3.0  3.0  3.0  1.0
#             Juntos Somos Mais Fortes                3.0  2.0  2.0  3.0  2.0
#             Liderança                               2.0  2.0  2.0  NaN  NaN
# BRWLMC      Compromisso com o Desenvolvimento       1.0  2.0  2.0  2.0  1.0
#             Foco                                    3.0  1.0  2.0  2.0  1.0
#             Influência                              2.0  2.0  1.0  2.0  2.0
#             Juntos Somos Mais Fortes                3.0  2.0  2.0  2.0  1.0
#             Liderança                               2.0  2.0  1.0  NaN  NaN
# BRWOD       Compromisso com o Desenvolvimento       2.0  1.0  2.0  2.0  2.0
#             Foco                                    1.0  2.0  2.0  2.0  2.0
#             Influência                              3.0  3.0  2.0  2.0  2.0
#             Juntos Somos Mais Fortes                2.0  2.0  2.0  3.0  2.0
#             Liderança                               2.0  2.0  3.0  2.0  2.0
# BRWRS1      Compromisso com o Desenvolvimento       2.0  2.0  2.0  2.0  3.0
#             Foco                                    1.0  3.0  3.0  2.0  2.0
#             Influência                              2.0  2.0  3.0  1.0  2.0
#             Juntos Somos Mais Fortes                2.0  3.0  2.0  2.0  3.0
#             Liderança                               1.0  2.0  2.0  NaN  NaN
#
#
# anoAv                                         2019
# colaborador comp
# BRAACN      Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         3.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          2.0
# BRAAF3      Compromisso com o Desenvolvimento  2.0
#             Foco                               3.0
#             Influência                         2.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          3.0
# BRAAMGM     Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         2.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          NaN
# BRAAS       Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         2.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          2.0
# BRABSG      Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         1.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          2.0
# BRACCJ1     Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         2.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          1.0
# ...                                            ...
# BRWBS2      Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         1.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          2.0
# BRWCM2      Compromisso com o Desenvolvimento  1.0
#             Foco                               2.0
#             Influência                         3.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          NaN
# BRWDM       Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         1.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          NaN
# BRWLMC      Compromisso com o Desenvolvimento  2.0
#             Foco                               3.0
#             Influência                         1.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          NaN
# BRWOD       Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         2.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          2.0
# BRWRS1      Compromisso com o Desenvolvimento  2.0
#             Foco                               2.0
#             Influência                         2.0
#             Juntos Somos Mais Fortes           2.0
#             Liderança                          1.0
#
# [1930 rows x 6 columns]

# %%
data = listaPdiMapeadoPorCompetencia.pivot_table(index=["colaborador","comp"], columns=['anoAv'], values="avaliacao")

# %%
data = pd.DataFrame(data.to_records())

# %%
data["2015_analisado"] = np.where(data['2014'] < data['2015'], 'Maior', np.where(data['2014'] > data['2015'], 'Menor', np.where(data['2014'] == data['2015'], 'Igual', 'Não Mapeado')))
data["2016_analisado"] = np.where(data['2015'] < data['2016'], 'Maior', np.where(data['2015'] > data['2016'], 'Menor', np.where(data['2015'] == data['2016'], 'Igual', 'Não Mapeado')))
data["2017_analisado"] = np.where(data['2016'] < data['2017'], 'Maior', np.where(data['2016'] > data['2017'], 'Menor', np.where(data['2016'] == data['2017'], 'Igual', 'Não Mapeado')))
data["2018_analisado"] = np.where(data['2017'] < data['2018'], 'Maior', np.where(data['2017'] > data['2018'], 'Menor', np.where(data['2017'] == data['2018'], 'Igual', 'Não Mapeado')))
data["2019_analisado"] = np.where(data['2018'] < data['2019'], 'Maior', np.where(data['2018'] > data['2019'], 'Menor', np.where(data['2018'] == data['2019'], 'Igual', 'Não Mapeado')))

# %%
analiseDados = data[['colaborador','comp','2015_analisado','2016_analisado','2017_analisado','2018_analisado','2019_analisado']]
analiseDados.set_index(['colaborador','comp'])
# Out:
#                                               2015_analisado 2016_analisado  \
# colaborador comp
# BRAACN      Compromisso com o Desenvolvimento          Igual          Maior
#             Foco                                       Maior          Igual
#             Influência                                 Igual          Menor
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Igual          Igual
# BRAAF3      Compromisso com o Desenvolvimento          Igual          Maior
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Maior
#             Juntos Somos Mais Fortes                   Menor          Igual
#             Liderança                                  Igual          Menor
# BRAAMGM     Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Igual
#             Juntos Somos Mais Fortes                   Igual          Maior
#             Liderança                                  Igual          Maior
# BRAAS       Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Maior          Igual
# BRABSG      Compromisso com o Desenvolvimento          Igual          Menor
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Menor
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Igual          Menor
# BRACCJ1     Compromisso com o Desenvolvimento          Menor          Maior
#             Foco                                       Menor          Igual
#             Influência                                 Igual          Menor
#             Juntos Somos Mais Fortes                   Igual          Menor
#             Liderança                                  Menor          Menor
# ...                                                      ...            ...
# BRWBS2      Compromisso com o Desenvolvimento          Maior          Igual
#             Foco                                       Maior          Igual
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Igual          Igual
#             Liderança                                  Igual          Igual
# BRWCM2      Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Maior          Igual
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Maior          Igual
#             Liderança                                  Igual          Maior
# BRWDM       Compromisso com o Desenvolvimento          Maior          Igual
#             Foco                                       Maior          Igual
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Menor          Igual
#             Liderança                                  Igual          Igual
# BRWLMC      Compromisso com o Desenvolvimento          Maior          Igual
#             Foco                                       Menor          Maior
#             Influência                                 Igual          Menor
#             Juntos Somos Mais Fortes                   Menor          Igual
#             Liderança                                  Igual          Menor
# BRWOD       Compromisso com o Desenvolvimento          Menor          Maior
#             Foco                                       Maior          Igual
#             Influência                                 Igual          Menor
#             Juntos Somos Mais Fortes                   Igual          Igual
#             Liderança                                  Igual          Maior
# BRWRS1      Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Maior          Igual
#             Influência                                 Igual          Maior
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Maior          Igual
#
#                                               2017_analisado 2018_analisado  \
# colaborador comp
# BRAACN      Compromisso com o Desenvolvimento          Menor          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Igual
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Menor          Maior
# BRAAF3      Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Maior          Maior
#             Influência                                 Menor          Igual
#             Juntos Somos Mais Fortes                   Igual          Igual
#             Liderança                                  Maior          Igual
# BRAAMGM     Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Igual
#             Juntos Somos Mais Fortes                   Menor          Igual
#             Liderança                            Não Mapeado    Não Mapeado
# BRAAS       Compromisso com o Desenvolvimento          Maior          Igual
#             Foco                                       Menor          Maior
#             Influência                                 Menor          Maior
#             Juntos Somos Mais Fortes                   Igual          Maior
#             Liderança                                  Igual          Igual
# BRABSG      Compromisso com o Desenvolvimento          Maior          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Igual          Igual
#             Liderança                                  Igual          Maior
# BRACCJ1     Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Maior          Menor
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Igual          Igual
#             Liderança                                  Maior          Menor
# ...                                                      ...            ...
# BRWBS2      Compromisso com o Desenvolvimento          Maior          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Igual
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Igual          Maior
# BRWCM2      Compromisso com o Desenvolvimento          Maior          Menor
#             Foco                                       Menor          Igual
#             Influência                                 Igual          Maior
#             Juntos Somos Mais Fortes                   Igual          Maior
#             Liderança                            Não Mapeado    Não Mapeado
# BRWDM       Compromisso com o Desenvolvimento          Igual          Menor
#             Foco                                       Igual          Menor
#             Influência                                 Igual          Menor
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                            Não Mapeado    Não Mapeado
# BRWLMC      Compromisso com o Desenvolvimento          Igual          Menor
#             Foco                                       Igual          Menor
#             Influência                                 Maior          Igual
#             Juntos Somos Mais Fortes                   Igual          Menor
#             Liderança                            Não Mapeado    Não Mapeado
# BRWOD       Compromisso com o Desenvolvimento          Igual          Igual
#             Foco                                       Igual          Igual
#             Influência                                 Igual          Igual
#             Juntos Somos Mais Fortes                   Maior          Menor
#             Liderança                                  Menor          Igual
# BRWRS1      Compromisso com o Desenvolvimento          Igual          Maior
#             Foco                                       Menor          Igual
#             Influência                                 Menor          Maior
#             Juntos Somos Mais Fortes                   Igual          Maior
#             Liderança                            Não Mapeado    Não Mapeado
#
#                                               2019_analisado
# colaborador comp
# BRAACN      Compromisso com o Desenvolvimento          Igual
#             Foco                                       Igual
#             Influência                                 Maior
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                                  Menor
# BRAAF3      Compromisso com o Desenvolvimento          Menor
#             Foco                                       Igual
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                                  Igual
# BRAAMGM     Compromisso com o Desenvolvimento          Igual
#             Foco                                       Igual
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                            Não Mapeado
# BRAAS       Compromisso com o Desenvolvimento          Menor
#             Foco                                       Igual
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Menor
#             Liderança                                  Igual
# BRABSG      Compromisso com o Desenvolvimento          Igual
#             Foco                                       Igual
#             Influência                                 Menor
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                                  Igual
# BRACCJ1     Compromisso com o Desenvolvimento          Igual
#             Foco                                       Igual
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                                  Igual
# ...                                                      ...
# BRWBS2      Compromisso com o Desenvolvimento          Menor
#             Foco                                       Igual
#             Influência                                 Menor
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                                  Menor
# BRWCM2      Compromisso com o Desenvolvimento          Igual
#             Foco                                       Maior
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Menor
#             Liderança                            Não Mapeado
# BRWDM       Compromisso com o Desenvolvimento          Maior
#             Foco                                       Maior
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                            Não Mapeado
# BRWLMC      Compromisso com o Desenvolvimento          Maior
#             Foco                                       Maior
#             Influência                                 Menor
#             Juntos Somos Mais Fortes                   Maior
#             Liderança                            Não Mapeado
# BRWOD       Compromisso com o Desenvolvimento          Igual
#             Foco                                       Igual
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Igual
#             Liderança                                  Igual
# BRWRS1      Compromisso com o Desenvolvimento          Menor
#             Foco                                       Igual
#             Influência                                 Igual
#             Juntos Somos Mais Fortes                   Menor
#             Liderança                            Não Mapeado
#
# [1930 rows x 5 columns]

# %%
analiseCompetenciaEntreAnos = analiseDados.melt(id_vars=['colaborador','comp'],value_vars=['2015_analisado','2016_analisado','2017_analisado','2018_analisado','2019_analisado'])
analiseCompetenciaEntreAnos.columns = ['colaborador','comp','anoAv','resultado']

analiseCompetenciaEntreAnos["anoAv"] = np.where(analiseCompetenciaEntreAnos["anoAv"] == "2015_analisado", '2015', np.where(analiseCompetenciaEntreAnos["anoAv"] == "2016_analisado", '2016', np.where(analiseCompetenciaEntreAnos["anoAv"] == "2017_analisado", '2017', np.where(analiseCompetenciaEntreAnos["anoAv"] == "2018_analisado", '2018',  np.where(analiseCompetenciaEntreAnos["anoAv"] == "2019_analisado", '2019', '')))))
analiseCompetenciaEntreAnos['anoAv'] = analiseCompetenciaEntreAnos.anoAv.astype(str)
listaPdiMapeadoPorCompetencia['anoAv'] = listaPdiMapeadoPorCompetencia.anoAv.astype(str)

# %% [markdown]
# ## Tabela final de Análise - PDI e Análise entre anos

# %%
tabelaFinal = pd.merge(analiseCompetenciaEntreAnos,listaPdiMapeadoPorCompetencia,how='left',on=['colaborador','comp','anoAv'])

# %%
tabelaFinal['pdiAnoAnterior'] = tabelaFinal['pdiAnoAnterior'].fillna('Não')
resultadosNaoMapeados = tabelaFinal
tabelaFinal = tabelaFinal[tabelaFinal.resultado != 'Não Mapeado']

# %% [markdown]
# ## Resultados incluindo competências "Não Mapeadas"

# %%
comPdi = tabelaFinal['pdiAnoAnterior'] == 'Sim'
semPdi = tabelaFinal['pdiAnoAnterior'] == 'Não'
resultadosComPdi = tabelaFinal[comPdi]
resultadosSemPdi = tabelaFinal[semPdi]

comPdi_2015 = resultadosComPdi['anoAv'] == '2015'
semPdi_2015 = resultadosSemPdi['anoAv'] == '2015'
resultadosComPdi_2015 = resultadosComPdi[comPdi_2015]
resultadosSemPdi_2015 = resultadosSemPdi[semPdi_2015]

comPdi_2016 = resultadosComPdi['anoAv'] == '2016'
semPdi_2016 = resultadosSemPdi['anoAv'] == '2016'
resultadosComPdi_2016 = resultadosComPdi[comPdi_2016]
resultadosSemPdi_2016 = resultadosSemPdi[semPdi_2016]

comPdi_2017 = resultadosComPdi['anoAv'] == '2017'
semPdi_2017 = resultadosSemPdi['anoAv'] == '2017'
resultadosComPdi_2017 = resultadosComPdi[comPdi_2017]
resultadosSemPdi_2017 = resultadosSemPdi[semPdi_2017]

comPdi_2018 = resultadosComPdi['anoAv'] == '2018'
semPdi_2018 = resultadosSemPdi['anoAv'] == '2018'
resultadosComPdi_2018 = resultadosComPdi[comPdi_2018]
resultadosSemPdi_2018 = resultadosSemPdi[semPdi_2018]

comPdi_2019 = resultadosComPdi['anoAv'] == '2019'
semPdi_2019 = resultadosSemPdi['anoAv'] == '2019'
resultadosComPdi_2019 = resultadosComPdi[comPdi_2019]
resultadosSemPdi_2019 = resultadosSemPdi[semPdi_2019]

# %% [markdown]
# ## Resultados Gerais

# %%
resultadosComPdi['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='Resultado das competências que tiveram o PDI mapeado no ano anterior')
plt.savefig('pdiMapeadoAnoAnterior.png', bbox_inches='tight')

# %%
resultadosSemPdi['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='Resultado das competências não que tiveram o PDI mapeado no ano anterior')
plt.savefig('pdiNaoMapeadoAnoAnterior.png', bbox_inches='tight')

# %% [markdown]
# ## [2015 x 2016] Resultados

# %%
analiseDados['2015_analisado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='Análise geral da avaliação de competências 2015 x 2016')
plt.savefig('avComp2015-2016.png', bbox_inches='tight')

# %%
resultadosComPdi_2015['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2016] Resultado das competências que tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiMapeado2015-2016.png', bbox_inches='tight')

# %%
resultadosSemPdi_2015['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2016] Resultado das competências que NÃO tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiNaoMapeado2015-2016.png', bbox_inches='tight')

# %% [markdown]
# ## [2015 x 2016] Resultados

# %%
analiseDados['2016_analisado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='Análise geral da avaliação de competências 2015 x 2016')
plt.savefig('avComp2015-2016.png', bbox_inches='tight')

# %%
resultadosComPdi_2016['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2016] Resultado das competências que tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiMapeado2015-2016.png', bbox_inches='tight')

# %%
resultadosSemPdi_2016['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2016] Resultado das competências que NÃO tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiNaoMapeado2015-2016.png', bbox_inches='tight')

# %% [markdown]
# ## [2016 x 2017] Resultados

# %%
analiseDados['2017_analisado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'],title='Análise geral da avaliação de competências 2016 x 2017')
plt.savefig('avComp2016-2017.png', bbox_inches='tight')

# %%
resultadosComPdi_2017['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2017] Resultado das competências que tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiMapeado2016-2017.png', bbox_inches='tight')

# %%
resultadosSemPdi_2017['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2017] Resultado das competências que NÃO tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiNaoMapeado2016-2017.png', bbox_inches='tight')

# %% [markdown]
# ## [2017 x 2018] Resultados

# %%
analiseDados['2018_analisado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'],title='Análise geral da avaliação de competências 2017 x 2018')
plt.savefig('avComp2017-2018.png', bbox_inches='tight')

# %%
resultadosComPdi_2018['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'],title='[2018] Resultado das competências que tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiMapeado2017-2018.png', bbox_inches='tight')

# %%
resultadosSemPdi_2018['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2018] Resultado das competências que NÃO tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiNaoMapeado2017-2018.png', bbox_inches='tight')

# %% [markdown]
# ## [2018 x 2019] Resultados

# %%
analiseDados['2019_analisado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'],title='Análise geral da avaliação de competências 2018 x 2019')
plt.savefig('avComp2018-2019.png', bbox_inches='tight')

# %%
resultadosComPdi_2019['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'],title='[2019] Resultado das competências que tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiMapeado2018-2019.png', bbox_inches='tight')

# %%
resultadosSemPdi_2019['resultado'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#b0efff', '#d0ffb0', '#ffb4b0'], title='[2019] Resultado das competências que NÃO tiveram o PDI mapeado no ano anterior')
plt.savefig('avCompPdiNaoMapeado2018-2019.png', bbox_inches='tight')

# %% [markdown]
# ## Gráfico de  barras empilhadas da avaliação de competência ao longo dos processos

# %% [markdown]
# # [2014x2015] Com PDI

# %%
mapeados_2015 = resultadosComPdi_2015['resultado'] != 'Não Mapeado'
resultadoComPdi_2015_excluindoNaoMapeados = resultadosComPdi_2015[mapeados_2015]
resultadoComPdi_2015_excluindoNaoMapeados
resultadoComPdi_2015_excluindoNaoMapeados_analisado = resultadoComPdi_2015_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoComPdi_2015_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoComPdi_2015_excluindoNaoMapeados_analisado.to_records())
resultadoComPdi_2015_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
resultadoComPdi_2015_excluindoNaoMapeados_analisado = resultadoComPdi_2015_excluindoNaoMapeados_analisado.fillna(0)
df = resultadoComPdi_2015_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento     53     37     11
# 1                               Foco     20     20     13
# 2                         Influência     44     21      5
# 3           Juntos Somos Mais Fortes     19     15      6
# 4                          Liderança     27     17      2

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2014x2015] Competências com PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %% [markdown]
# # [2014x2015] Sem PDI

# %%
mapeados_2015 = resultadosSemPdi_2015['resultado'] != 'Não Mapeado'
resultadoSemPdi_2015_excluindoNaoMapeados = resultadosSemPdi_2015[mapeados_2015]
resultadoSemPdi_2015_excluindoNaoMapeados
resultadoSemPdi_2015_excluindoNaoMapeados_analisado = resultadoSemPdi_2015_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoSemPdi_2015_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoSemPdi_2015_excluindoNaoMapeados_analisado.to_records())
resultadoSemPdi_2015_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
df = resultadoSemPdi_2015_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento    184     83     49
# 1                               Foco    203     98     45
# 2                         Influência    168    102     55
# 3           Juntos Somos Mais Fortes    197    111     46
# 4                          Liderança    206     92     50

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2014x2015] Competências sem PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - SemPDI2015-2016.png', bbox_inches='tight')

# %% [markdown]
# # [2015x2016] Com PDI

# %%
mapeados_2016 = resultadosComPdi_2016['resultado'] != 'Não Mapeado'
resultadoComPdi_2016_excluindoNaoMapeados = resultadosComPdi_2016[mapeados_2016]
resultadoComPdi_2016_excluindoNaoMapeados
resultadoComPdi_2016_excluindoNaoMapeados_analisado = resultadoComPdi_2016_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoComPdi_2016_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoComPdi_2016_excluindoNaoMapeados_analisado.to_records())
resultadoComPdi_2016_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
resultadoComPdi_2016_excluindoNaoMapeados_analisado = resultadoComPdi_2016_excluindoNaoMapeados_analisado.fillna(0)
df = resultadoComPdi_2016_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento   24.0   11.0   12.0
# 1                               Foco   10.0    7.0    0.0
# 2                         Influência   16.0    8.0    1.0
# 3           Juntos Somos Mais Fortes    5.0    4.0    1.0
# 4                          Liderança    6.0    4.0    2.0

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2015x2016] Competências com PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - ComPDI2015-2016.png', bbox_inches='tight')

# %% [markdown]
# # [2015x2016] Sem PDI

# %%
mapeados_2016 = resultadosSemPdi_2016['resultado'] != 'Não Mapeado'
resultadoSemPdi_2016_excluindoNaoMapeados = resultadosSemPdi_2016[mapeados_2016]
resultadoSemPdi_2016_excluindoNaoMapeados
resultadoSemPdi_2016_excluindoNaoMapeados_analisado = resultadoSemPdi_2016_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoSemPdi_2016_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoSemPdi_2016_excluindoNaoMapeados_analisado.to_records())
resultadoSemPdi_2016_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
df = resultadoSemPdi_2016_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento    233     68     54
# 1                               Foco    236     88     45
# 2                         Influência    208     87     69
# 3           Juntos Somos Mais Fortes    242     77     58
# 4                          Liderança    206    106     64

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2015x2016] Competências sem PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - SemPDI2015-2016.png', bbox_inches='tight')

# %% [markdown]
# # [2016x2017] Com PDI

# %%
mapeados_2017 = resultadosComPdi_2017['resultado'] != 'Não Mapeado'
resultadoComPdi_2017_excluindoNaoMapeados = resultadosComPdi_2017[mapeados_2017]
resultadoComPdi_2017_excluindoNaoMapeados
resultadoComPdi_2017_excluindoNaoMapeados_analisado = resultadoComPdi_2017_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoComPdi_2017_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoComPdi_2017_excluindoNaoMapeados_analisado.to_records())
resultadoComPdi_2017_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
df = resultadoComPdi_2017_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento     19      6     15
# 1                               Foco     18      2      1
# 2                         Influência     10      6      7
# 3           Juntos Somos Mais Fortes      2      8      1
# 4                          Liderança      6      3      5

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2016x2017] Competências com PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - ComPDI2016-2017.png', bbox_inches='tight')

# %% [markdown]
# # [2016x2017] Sem PDI

# %%
mapeados_2017 = resultadosSemPdi_2017['resultado'] != 'Não Mapeado'
resultadoSemPdi_2017_excluindoNaoMapeados = resultadosSemPdi_2017[mapeados_2017]
resultadoSemPdi_2017_excluindoNaoMapeados
resultadoSemPdi_2017_excluindoNaoMapeados_analisado = resultadoSemPdi_2017_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoSemPdi_2017_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoSemPdi_2017_excluindoNaoMapeados_analisado.to_records())
resultadoSemPdi_2017_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
df = resultadoSemPdi_2017_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento    201     57     98
# 1                               Foco    228     70     70
# 2                         Influência    213     64     90
# 3           Juntos Somos Mais Fortes    228     81     69
# 4                          Liderança    123     53     53

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2016x2017] Competências sem PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - SemPDI2016-2017.png', bbox_inches='tight')

# %% [markdown]
# # [2017x2018] Com PDI

# %%
mapeados_2018 = resultadosComPdi_2018['resultado'] != 'Não Mapeado'
resultadoComPdi_2018_excluindoNaoMapeados = resultadosComPdi_2018[mapeados_2018]
resultadoComPdi_2018_excluindoNaoMapeados
resultadoComPdi_2018_excluindoNaoMapeados_analisado = resultadoComPdi_2018_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoComPdi_2018_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoComPdi_2018_excluindoNaoMapeados_analisado.to_records())
resultadoComPdi_2018_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
resultadoComPdi_2018_excluindoNaoMapeados_analisado = resultadoComPdi_2018_excluindoNaoMapeados_analisado.fillna(0)
df = resultadoComPdi_2018_excluindoNaoMapeados_analisado

df['Maior'] = df['Maior'].fillna(value=0)
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento    7.0    7.0    1.0
# 1                               Foco    4.0    3.0    1.0
# 2                         Influência    2.0    6.0    1.0
# 3           Juntos Somos Mais Fortes    3.0    2.0    0.0
# 4                          Liderança    5.0    1.0    0.0

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2017x2018] Competências com PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - ComPDI2017-2018.png', bbox_inches='tight')

# %% [markdown]
# # [2017x2018] Sem PDI

# %%
mapeados_2018 = resultadosSemPdi_2018['resultado'] != 'Não Mapeado'
resultadoSemPdi_2018_excluindoNaoMapeados = resultadosSemPdi_2018[mapeados_2018]
resultadoSemPdi_2018_excluindoNaoMapeados
resultadoSemPdi_2018_excluindoNaoMapeados_analisado = resultadoSemPdi_2018_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoSemPdi_2018_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoSemPdi_2018_excluindoNaoMapeados_analisado.to_records())
resultadoSemPdi_2018_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
df = resultadoSemPdi_2018_excluindoNaoMapeados_analisado
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento    248     71     55
# 1                               Foco    242     82     54
# 2                         Influência    227     82     69
# 3           Juntos Somos Mais Fortes    228     84     69
# 4                          Liderança    145     45     45

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2017x2018] Competências sem PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - SemPDI2017-2018.png')

# %% [markdown]
# # [2018x2019] Com PDI

# %%
mapeados_2019 = resultadosComPdi_2019['resultado'] != 'Não Mapeado'
resultadoComPdi_2019_excluindoNaoMapeados = resultadosComPdi_2019[mapeados_2019]
resultadoComPdi_2019_excluindoNaoMapeados
resultadoComPdi_2019_excluindoNaoMapeados_analisado = resultadoComPdi_2019_excluindoNaoMapeados.pivot_table(index=['comp'],columns=['resultado'], values=['anoAv'],aggfunc='count')
resultadoComPdi_2019_excluindoNaoMapeados_analisado = pd.DataFrame(resultadoComPdi_2019_excluindoNaoMapeados_analisado.to_records())
resultadoComPdi_2019_excluindoNaoMapeados_analisado.columns = ['comp','Igual','Maior','Menor']
resultadoComPdi_2019_excluindoNaoMapeados_analisado = resultadoComPdi_2019_excluindoNaoMapeados_analisado.fillna(0)
df = resultadoComPdi_2019_excluindoNaoMapeados_analisado

df['Maior'] = df['Maior'].fillna(value=0)
df
# Out:
#                                 comp  Igual  Maior  Menor
# 0  Compromisso com o Desenvolvimento    2.0    0.0    6.0
# 1                               Foco    2.0    0.0    2.0
# 2                         Influência    2.0    1.0    0.0
# 3           Juntos Somos Mais Fortes    2.0    0.0    2.0
# 4                          Liderança    1.0    0.0    0.0

# %%
# Create a figure with a single subplot
f, ax = plt.subplots(1, figsize=(10,5))
colunas = ['Igual','Maior','Menor']
# Set bar width at 1
bar_width = 1

# positions of the left bar-boundaries
bar_l = [i for i in range(len(df['Igual']))] 

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l] 
tick_pos_div = [i for i in bar_l] 

# Create the total score for each participant
totals = [i+j+k for i,j,k in zip(df['Igual'], df['Maior'], df['Menor'])]

# Create the percentage of the total score the pre_score value for each participant was
pre_rel = [i / j * 100 for  i,j in zip(df['Igual'], totals)]
pre_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Igual'], totals)]

# Create the percentage of the total score the mid_score value for each participant was
mid_rel = [i / j * 100 for  i,j in zip(df['Maior'], totals)]
mid_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Maior'], totals)] 
mid_rel_pos2 = [i + j for  i,j in zip(pre_rel, mid_rel_pos)] 

# Create the percentage of the total score the post_score value for each participant was
post_rel = [i / j * 100 for  i,j in zip(df['Menor'], totals)]
post_rel_pos = [(i / j * 100)/2 for  i,j in zip(df['Menor'], totals)]
post_rel_pos2 = [i + j + y for  i,j,y in zip(pre_rel, mid_rel,post_rel_pos)]

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using pre_rel data
       pre_rel, 
       # labeled 
       label='Igual', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#b0efff',
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, pre_rel_pos, pre_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using mid_rel data
       mid_rel, 
       # with pre_rel
       bottom=pre_rel, 
       # labeled 
       label='Maior', 
       # with alpha
       alpha=0.9, 
       # with color
       color='#d0ffb0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )

for xpos, ypos, yval in zip(tick_pos_div, mid_rel_pos2, mid_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Create a bar chart in position bar_1
ax.bar(bar_l, 
       # using post_rel data
       post_rel, 
       # with pre_rel and mid_rel on bottom
       bottom=[i+j for i,j in zip(pre_rel, mid_rel)], 
       # labeled 
       label='Menor',
       # with alpha
       alpha=0.9, 
       # with color
       color='#ffb4b0', 
       # with bar width
       width=bar_width,
       # with border color
       edgecolor='white'
       )
for xpos, ypos, yval in zip(tick_pos_div, post_rel_pos2, post_rel):
    plt.text(xpos, ypos, "%.1f"%yval + '%', ha="center", va="center",color='#000000')

# Set the ticks to be first names
plt.xticks(tick_pos, df['comp'])
ax.set_ylabel("Percentual")
ax.set_xlabel("")

# Let the borders of the graphic
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
plt.ylim(-10, 110)

# rotate axis labels
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')


# shot plot
plt.title('[2017x2018] Competências com PDI mapeado no ano anterior')
plt.legend(labels = colunas,fontsize= 14, loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.savefig('barrasEmpilhadas - ComPDI2017-2018.png', bbox_inches='tight')

# %% [markdown]
# ## Análise não mapeados

# %%
naoMapeadosComPdi = resultadosNaoMapeados['pdiAnoAnterior'] == 'Sim'
naoMapeadosSemPdi = resultadosNaoMapeados['pdiAnoAnterior'] == 'Não'
resultadosNaoMapeadosComPdi = resultadosNaoMapeados[naoMapeadosComPdi]
resultadosNaoMapeadosSemPdi = resultadosNaoMapeados[naoMapeadosSemPdi]

naoMapeados_2015 = resultadosNaoMapeados['anoAv'] == '2015'
resultadosNaoMapeados_2015 = resultadosNaoMapeados[naoMapeados_2015]

naoMapeados_2016 = resultadosNaoMapeados['anoAv'] == '2016'
resultadosNaoMapeados_2016 = resultadosNaoMapeados[naoMapeados_2016]

naoMapeados_2017 = resultadosNaoMapeados['anoAv'] == '2017'
resultadosNaoMapeados_2017 = resultadosNaoMapeados[naoMapeados_2017]

naoMapeados_2018 = resultadosNaoMapeados['anoAv'] == '2018'
resultadosNaoMapeados_2018 = resultadosNaoMapeados[naoMapeados_2018]

# %%
resultadosNaoMapeados_2015["resultado"] = np.where(resultadosNaoMapeados_2015['resultado'] != 'Não Mapeado', 'Mapeado','Não Mapeado')

resultadosNaoMapeados_2016["resultado"] = np.where(resultadosNaoMapeados_2016['resultado'] != 'Não Mapeado', 'Mapeado','Não Mapeado')

resultadosNaoMapeados_2017["resultado"] = np.where(resultadosNaoMapeados_2017['resultado'] != 'Não Mapeado', 'Mapeado','Não Mapeado')

resultadosNaoMapeados_2018["resultado"] = np.where(resultadosNaoMapeados_2018['resultado'] != 'Não Mapeado', 'Mapeado','Não Mapeado')
# Out:
# C:\Users\kaiom\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kaiom\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\kaiom\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\kaiom\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
resultadosNaoMapeados_2015["resultado"].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#d0ffb0', '#f77676'], title='[2014 x 2015] Análise de competências mapeadas ').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
resultadosNaoMapeados_2016["resultado"].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#d0ffb0', '#f77676'], title='[2015 x 2016] Análise de competências mapeadas ').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
resultadosNaoMapeados_2017["resultado"].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#d0ffb0', '#f77676'], title='[2016 x 2017] Análise de competências mapeadas ').set_ylabel('')
# Out:
# Text(0,0.5,'')

# %%
resultadosNaoMapeados_2018["resultado"].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),colors=['#d0ffb0', '#f77676'], title='[2017 x 2018] Análise de competências mapeadas ').set_ylabel('')
# Out:
# Text(0,0.5,'')
